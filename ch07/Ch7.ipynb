# %%
priceList=[]
priceSum = 0
for i in range(1,5):
    p = int(input(f"請輸入{i}個月的支出金額"))
    priceSum =priceSum + p
    priceList.append(p)
priceList.sort()
print(f"max:{priceList[len(priceList)-1]}") 
print(f"min:{priceList[0]}")
print(priceSum)    
print(priceList) 

print(sum(priceList)) 
print(max(priceList))    
print(min(priceList))
# Out:
# 請輸入1個月的支出金額6000
# 請輸入2個月的支出金額5000
# 請輸入3個月的支出金額3000
# 請輸入4個月的支出金額4000
# max:6000
# min:3000
# 18000
# [3000, 4000, 5000, 6000]
# 18000
# 6000
# 3000

# %%
num1 = 10
num2 = 0
try:
    print(num1/num2)
except ZeroDivisionError :
    print("有問題發生:","ZeroDivisionError")
print("TEST!!")
# Out:
# 有問題發生: ZeroDivisionError
# TEST!!

# %%
myList = [1,2,3]
try:
    while True:
        print("TEST1")
        print(myList.pop())
        print("TEST2")
except:
    pass
# Out:
# TEST1
# 3
# TEST2
# TEST1
# 2
# TEST2
# TEST1
# 1
# TEST2
# TEST1

# %%
def testScore(score:int):
    if score < 0 or score > 100:
        print("錯誤的成績")
        return
    print("score:",score)    
    #score是0~100顯示成績
    #不在範圍內 錯誤的成績
print("Test1!")
testScore(-1)
print("Test2!")
# Out:
# Test1!
# 錯誤的成績
# Test2!

# %% [markdown]
# ### 使用raise 拋出例外

# %%
def testScore(score:int):
    if score < 0 or score > 100:
        raise OverflowError("錯誤的成績")
    print("score:",score)    
print("Test1!")
testScore(-1)
print("Test2!")
# Out:
# Test1!
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[14], line 6
#       4     print("score:",score)
#       5 print("Test1!")
# ----> 6 testScore(-1)
#       7 print("Test2!")
#
# Cell In[14], line 3, in testScore(score)
#       1 def testScore(score:int):
#       2     if score < 0 or score > 100:
# ----> 3         raise OverflowError("錯誤的成績")
#       4     print("score:",score)
#
# OverflowError: 錯誤的成績

# %%
n1 = 10
n2 = 0
myList=[1,2,3]
try: 
    #n1/n2
    #myList[10]
    myListx.pop()
except ZeroDivisionError as ex:
    print("ZeroDivisionError:",ex)
except IndexError as ex:
    print("IndexError:",ex)
except Exception as ex: #除了以上其他的錯誤
    print("Exception",ex)
# Out:
# Exception name 'myListx' is not defined

# %% [markdown]
# ### 正規表示式
# ![01.png](attachment:01.png)

# %% [markdown]
# ![02.png](attachment:02.png)

# %%
import re
s = "Tim's phone numbers are 12345-41521 and 78963-85214"
match = re.findall(r"\d",s)
print(match)
# Out:
# ['1', '2', '3', '4', '5', '4', '1', '5', '2', '1', '7', '8', '9', '6', '3', '8', '5', '2', '1', '4']

# %% [markdown]
# ![03.png](attachment:03.png)

# %%
import re
s = "Tim's phone numbers are 12345-41521 and 78963-85214"
match = re.findall(r"\d{5}",s)
print(match)
# Out:
# ['12345', '41521', '78963', '85214']

# %% [markdown]
# ![04.png](attachment:04.png)

# %%
import  re
s="Python was conceiaaaaaaaaaaaaaaaaaaaved in the late 1980s by Guido van Rossum"
match = re.findall(r"[a-t]",s)
print(match)
match2 = re.findall(r"[a-t]{2}",s)
print(match2)
match3 = re.findall(r"[a-t]{3,6}",s)
print(match3)
match4 = re.findall(r"[a-t]{4,}",s)
print(match4)
# Out:
# ['t', 'h', 'o', 'n', 'a', 's', 'c', 'o', 'n', 'c', 'e', 'i', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'e', 'd', 'i', 'n', 't', 'h', 'e', 'l', 'a', 't', 'e', 's', 'b', 'i', 'd', 'o', 'a', 'n', 'o', 's', 's', 'm']
# ['th', 'on', 'as', 'co', 'nc', 'ei', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'ed', 'in', 'th', 'la', 'te', 'id', 'an', 'os']
# ['thon', 'concei', 'aaaaaa', 'aaaaaa', 'aaaaaa', 'the', 'late', 'ido', 'oss']
# ['thon', 'conceiaaaaaaaaaaaaaaaaaaa', 'late']

# %% [markdown]
# ![05.png](attachment:05.png)

# %%
import re
pattern = re.compile(r"\d+")
r1 = pattern.findall("hell12o 12345 6789")
r2 = pattern.findall("abc 1545531 8465 456")
print(r1)
print(r2)
# Out:
# ['12', '12345', '6789']
# ['1545531', '8465', '456']

# %%
import re
str1 = "abc1d abcdd abc2d abc aaaa"
print(re.findall(r"abcd?",str1))
print(re.findall(r"abcd*",str1))
print(re.findall(r"abcd+",str1))
# Out:
# ['abc', 'abcd', 'abc', 'abc']
# ['abc', 'abcdd', 'abc', 'abc']
# ['abcdd']

# %% [markdown]
# ### split方法
# ![06.png](attachment:06.png)

# %%
import re
text = "one,two,ten"
v1 = re.split(",",text)
print(v1)
print(v1[0])
v2 = re.split(",",text,1)
print(v2)
# Out:
# ['one', 'two', 'ten']
# one
# ['one', 'two,ten']

# %% [markdown]
# ### SUB方法
# ![07.png](attachment:07.png)

# %%
import re
inputStr = "This is Python.That is Java,This is SQLite"
nStr = inputStr.replace("is","-")
print(nStr)
# Out:
# Th- - Python.That - Java,Th- - SQLite

# %%
import re
inputStr = "This is Python.That is Java,This is SQLite"
# \b 單詞邊界 空白無字的
nStr = re.sub(r"\bis\b","-",inputStr)
print(nStr)
# Out:
# This - Python.That - Java,This - SQLite

# %% [markdown]
# ### 物件導向入門

# %%
class Employee:
    pass

# %%
class Employee:
    pass
emp = Employee() #建立物件
print(type(emp))
# Out:
# <class '__main__.Employee'>

# %%
class Employee:
    pass
emp = Employee() #建立物件
print(type(emp))
emp.name = "Ken"
emp.salary = 50000
print(emp.name,emp.salary)
# Out:
# <class '__main__.Employee'>
# Ken 50000

# %%
class Employee:
    pass
emp = Employee() #建立物件
print(type(emp))
emp.name = "Ken" #建立屬性
emp.salary = 50000
print(emp.name,emp.salary)
emp2 = Employee()
print(emp2.name)
# Out:
# <class '__main__.Employee'>
# Ken 50000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 9
#       7 print(emp.name,emp.salary)
#       8 emp2 = Employee()
# ----> 9 print(emp2.name)
#
# AttributeError: 'Employee' object has no attribute 'name'

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
emp1 = Employee("Ken",25000)
print(emp1.name)
print(emp1.salary)
# Out:
# Ken
# 25000

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
emp1 = Employee("Ken",25000)
print(emp1.name)
print(emp1.salary)
emp2 = Employee("vivian",50000)
print(emp2.name)
print(emp2.salary)
# Out:
# Ken
# 25000
# vivian
# 50000

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
    def printInfo(self):
        print("name:",self.name,"salary:",self.salary)
emp1 = Employee("Ken",25000)
emp1.printInfo()
emp2 = Employee("vivian",50000)
emp2.printInfo()
# Out:
# name: Ken salary: 25000
# name: vivian salary: 50000

# %% [markdown]
# ### 繼承

# %%
class Animal:
    def __init__(self,name,age=0):
        self.name = name
        self.age = age
    def printInfo(self):
        print("資訊:",self.name,self.age)
an1 = Animal("BOBO")
an1.printInfo()
an2 = Animal("LULU",5)
an2.printInfo()
# Out:
# 資訊: BOBO 0
# 資訊: LULU 5

# %%
class cat:
    pass
cat1 = cat("Kitty",3)
cat1.printInfo()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 class cat:
#       2     pass
# ----> 3 cat1 = cat("Kitty",3)
#       4 cat1.printInfo()
#
# TypeError: cat() takes no arguments

# %%
class cat(Animal):
    pass
cat1 = cat("Kitty",3)
cat1.printInfo()
# Out:
# Kitty 3

# %%
class Dog(Animal):
    pass
dog1 = Dog("kiki",2)
dog1.printInfo()
# Out:
# kiki 2

# %%
class cat(Animal):
    def printInfo(self):
        print("C:",self.name,self.age)
cat1 = cat("Kitty",3)
cat1.printInfo()
# Out:
# C: Kitty 3

# %%
 class Dog(Animal):
    def printInfo(self):
        print("D:",end="")
        super().printInfo() #super()呼叫父類別的東西
dog1 = Dog("kiki",2)
dog1.printInfo()
# Out:
# D:資訊: kiki 2

# %% [markdown]
# ### 多重繼承與初始化方法
# ![08.png](attachment:08.png)

# %%
class S:
    def method1(self):
        print("S method1")
    def method2(self):
        print("S method2")
class A(S):
    def method3(self):
        print("A method3")
class B(S):
    def method2(self):
        print("B method2")
    def method3(self):
        print("B method3")
class C(A,B):
    def method4(self):
        print("C method4")
c=C()
c.method4()
c.method3()
c.method2()
c.method1()
# Out:
# C method4
# A method3
# B method2
# S method1

# %% [markdown]
# ### str可輸出物件的內容

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
# Out:
# <__main__.Point object at 0x0000028E6DCBB750>
# <__main__.Point object at 0x0000028E6EE49050>

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
# Out:
# (2,3)
# (-1,2)

# %% [markdown]
# ![09.png](attachment:09.png)

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
p3 = p1+p2
# Out:
# (2,3)
# (-1,2)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 11
#       9 print(p1)
#      10 print(p2)
# ---> 11 p3 = p1+p2
#
# TypeError: unsupported operand type(s) for +: 'Point' and 'Point'

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):
        x = self.x+other.x
        y = self.y+other.y
        return Point(x,y)
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
p3 = p1+p2
print(p3)
# Out:
# (2,3)
# (-1,2)
# (1,5)

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):
        x = self.x+other.x
        y = self.y+other.y
        return Point(x,y)
    def __len__(self):
        myLen = (self.x**2) + (self.y**2)
        return myLen
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
p3 = p1+p2
print(p3)
print(len(p1))
# Out:
# (2,3)
# (-1,2)
# (1,5)
# 13

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):
        x = self.x+other.x
        y = self.y+other.y
        return Point(x,y)
    def __len__(self):
        myLen = (self.x**2) + (self.y**2)
        return myLen
p1 = Point(2,3)
p2 = Point(-1,2)
p3 = Point(9,11)
p4 = Point(7,12)
pointList = [p1,p2,p3,p4]
pointList.sort()
for p in pointList:
    print(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 19
#      17 p4 = Point(7,12)
#      18 pointList = [p1,p2,p3,p4]
# ---> 19 pointList.sort()
#      20 for p in pointList:
#      21     print(p)
#
# TypeError: '<' not supported between instances of 'Point' and 'Point'

# %%
class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):
        x = self.x+other.x
        y = self.y+other.y
        return Point(x,y)
    def __len__(self):
        myLen = (self.x**2) + (self.y**2)
        return myLen
    def __lt__(self,other):
        selfLen = len(self)
        otherLen = len(other)
        return selfLen < otherLen
p1 = Point(2,3)
p2 = Point(-1,2)
p3 = Point(9,11)
p4 = Point(7,12)
print(p1<p2)
print(p1>p2)
pointList = [p1,p2,p3,p4]
pointList.sort()
for p in pointList:
    print(p)
# Out:
# False
# True
# (-1,2)
# (2,3)
# (7,12)
# (9,11)

# %% [markdown]
# ### 目錄管理

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HHH\ai_python_20240316\Ch7

# %%
import os
# 切換路徑
#os.chdir(r"C:\Users\HHH\ai_python_20240316\Ch7")
print(os.getcwd())
myDir = os.listdir()
for f in myDir:
    print(f)
# Out:
# C:\Users\HHH\ai_python_20240316\Ch7
# .ipynb_checkpoints
# Ch7.ipynb

# %%
from os import listdir
from os.path import isfile,isdir
files = listdir()
print(files)
for f in files:
    if isfile(f):
        print("檔案:",f)
    elif isdir(f):
         print("目錄:",f)
# Out:
# ['.ipynb_checkpoints', 'Ch7.ipynb', 'Dir1', 'Dir2']
# 目錄: .ipynb_checkpoints
# 檔案: Ch7.ipynb
# 目錄: Dir1
# 目錄: Dir2

# %%
from os import walk
import os
print(os.getcwd())
mypath = "."
for root,dirs,files in walk(mypath):
    print("路徑:",root)
    print("  目錄:",dirs)
    print("  檔案:",files)
# Out:
# C:\Users\HHH\ai_python_20240316\Ch7
# 路徑: .
#   目錄: ['.ipynb_checkpoints', 'Dir1', 'Dir2']
#   檔案: ['Ch7.ipynb']
# 路徑: .\.ipynb_checkpoints
#   目錄: []
#   檔案: ['Ch7-checkpoint.ipynb']
# 路徑: .\Dir1
#   目錄: []
#   檔案: ['Test1.txt', 'Test2.txt']
# 路徑: .\Dir2
#   目錄: ['Dir2_1']
#   檔案: ['Test2.txt']
# 路徑: .\Dir2\Dir2_1
#   目錄: []
#   檔案: ['Test2.txt']
